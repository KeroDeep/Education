# %%
def building_piglet():
    piglet = "Haф-Haф"

# %%
print(piglet)

# %%
piglet_2= "Ниф-ниф"

# %%
def building_piglet():
    piglet = "Hap-Hap"
    print(piglet_2)

# %%
building_piglet()

# %% [markdown]
# ## Схожие перменные:

# %%
def print_number():

  number = 15
  print(number)

# %%
number = -3

print_number()
print(number)

# %% [markdown]
# ## Ключевое слово **global**

# %%
piglet_2 = "Ниф-ниф"

def building_piglet():
      piglet_2 = "Haф-Haф"

      print(piglet_2)

# %%
building_piglet()

print(piglet_2)

# %%
piglet_2 = "Ниф-ниф"

def building_piglet():
      global piglet_2
      piglet_2 = "Haф-Haф"

      print(piglet_2)

# %%
building_piglet()

print(piglet_2)
